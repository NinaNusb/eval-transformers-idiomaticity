# %% [markdown]
# # Preprocessing the dataset

# %% [markdown]
# This file shows how the preprocessing is done but it's all centered in a single function that is directly called in other ntbks.

# %%
import os
import torch
import json
import pandas as pd
from itertools import chain

from utils.data_processing import *

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
torch.cuda.is_available()

# %load_ext autoreload
# %autoreload 2

# %%
#----------------------------- Retrieve data -----------------------------#
with open("../data/en_TaskIndependentData.json", "r") as file:
    data = json.load(file)

columns = zip(*chain(*chain(*data.values())))
column_names = ["id", "mwe", "literal_meaning", "_1", "_2", "_3", "proper", "meta", "0/1", "fine_grained", "prior", "sentence", "after", "source"]
data_df = pd.DataFrame({name: col for name, col in zip(column_names, columns)})

# Drop irrelevant columns
data_df = data_df.drop(["proper", "meta", "source"], axis=1)
init_len = len(data_df)

# Drop proper nouns and metaphors
data_df = data_df[~(data_df['fine_grained'].isin(['Proper Noun', 'Meta Usage']))]
print(f"We drop {init_len - len(data_df)} rows out of {init_len}.")

data_df.head()
# Out:
# We drop 777 rows out of 4645.
#     id           mwe literal_meaning    _1    _2    _3  0/1  fine_grained  \
# 0  150  mailing list    address list  None  None  None    1  address list
# 1  150  mailing list    address list  None  None  None    1  address list
# 2  150  mailing list    address list  None  None  None    1  address list
# 3  150  mailing list    address list  None  None  None    1  address list
# 4  150  mailing list    address list  None  None  None    1  address list
#
#                                                prior  \
# 0  Every registered voter 65 and older who was no...
# 1  To the best of the AAFP's knowledge, the spons...
# 2  Once the program is running, the payments coul...
# 3  Red Hat, Cisco, and Google were involved in th...
# 4  This optional step could save considerable mon...
#
#                                             sentence  \
# 0  The Secretary of State’s office became aware o...
# 1  Organizations and individuals may rent the AAF...
# 2  TDHCA will be providing updates on how to appl...
# 3  All major Linux distributions also received th...
# 4  Larger and active mailing lists (e.g., more th...
#
#                                                after
# 0  I’m no mathematician, but I said, ‘We have a p...
# 1  The AAFP's Marketing Research Department must ...
# 2  The program comes after renters have spent mon...
# 3  We assume that smaller and other downstream ve...
# 4  These database management tools allow for batc...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3868 entries, 0 to 4644
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3868 non-null   int64
#  1   mwe              3868 non-null   object
#  2   literal_meaning  3868 non-null   object
#  3   _1               3868 non-null   object
#  4   _2               3868 non-null   object
#  5   _3               3868 non-null   object
#  6   0/1              3868 non-null   int64
#  7   fine_grained     3868 non-null   object
#  8   prior            3868 non-null   object
#  9   sentence         3868 non-null   object
#  10  after            3868 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 362.6+ KB

# %%
data_df[(data_df["literal_meaning"] == "None") & (data_df["_1"] != 'None')]
# Out:
# Empty DataFrame
# Columns: [id, mwe, literal_meaning, _1, _2, _3, 0/1, fine_grained, prior, sentence, after]
# Index: []

# %%
filtered_rows = data_df[(data_df["_1"] == "None") & (data_df["_2"] != 'None')]

filtered_rows
# Out:
#       id              mwe literal_meaning    _1           _2    _3  0/1  \
# 277   12  ancient history         history  None  in the past  None    1
# 278   12  ancient history         history  None  in the past  None    1
# 279   12  ancient history         history  None  in the past  None    1
# 280   12  ancient history         history  None  in the past  None    1
# 281   12  ancient history         history  None  in the past  None    1
# ...   ..              ...             ...   ...          ...   ...  ...
# 2050  93       baby blues      depression  None    blue eyes  None    1
# 2051  93       baby blues      depression  None    blue eyes  None    1
# 2052  93       baby blues      depression  None    blue eyes  None    0
# 2053  93       baby blues      depression  None    blue eyes  None    0
# 2054  93       baby blues      depression  None    blue eyes  None    0
#
#      fine_grained                                              prior  \
# 277       history  Keeping up to date with international studies ...
# 278       history  Rather than carrying out monographic studies o...
# 279       history  COINTELPRO is a stark illustration of how the ...
# 280       history  The change is a declaration of purpose: to lea...
# 281       history       What kind of student would this course suit?
# ...           ...                                                ...
# 2050   depression                                  Doctor Reid said.
# 2051   depression  I was taking my work home, basically," she sai...
# 2052    blue eyes                       His eyes are just stunners!"
# 2053    blue eyes  They ended up loading up so many things, I cou...
# 2054    blue eyes  This will deliver images that are clear and co...
#
#                                                sentence  \
# 277   Brazilian specificity lies in our experience w...
# 278   Today, the country has important researchers i...
# 279   To disabuse anyone of the comforting delusion ...
# 280   There’s a more interesting story to be told ab...
# 281   This course will suit anyone fascinated by anc...
# ...                                                 ...
# 2050  Doctor Reid stated when she sought help her ph...
# 2051  After giving birth to her second child and exp...
# 2052  Carissa said of Matteo's baby blues, which he ...
# 2053  And she wasn't the only one taken aback by DiC...
# 2054  Say goodbye to red eye: Baby's bright eyes are...
#
#                                                   after
# 277   Studying ancient history in Brazil today has t...
# 278   Keeping up to date with international studies ...
# 279   The Partnership for Civil Justice obtained doc...
# 280   It seems to me the really crucial mover in his...
# 281   It will appeal to you if you enjoy the challen...
# ...                                                 ...
# 2050  However, Liz Moore, a Therapist LLMSW, works f...
# 2051  With the rise of the Norse myth through Marvel...
# 2052  As Nikki and Brie went on to play a game of "T...
# 2053  O'Driscoll also noted, “He had the bluest eyes...
# 2054  Use a camera with a c lose-up scene mode that ...
#
# [88 rows x 11 columns]

# %%
# Below are the dropped single-meaning-mwe rows indices. Among them: 3730, 2813
data_df.iloc[3730]
# Out:
# id                                                               265
# mwe                                                        leap year
# literal_meaning                                            jump year
# _1                                                   bissextile year
# _2                                                              None
# _3                                                              None
# 0/1                                                                0
# fine_grained                                         bissextile year
# prior              In China, for example, the leap year has an ex...
# sentence           Likewise, the Ethiopian calendar consists of 1...
# after              Hebrew and Buddhist ancient calendars also fol...
# Name: 4487, dtype: object

# %%
data_df[data_df['mwe'] == 'leap year']
# 'leap year' has 2 registred possible meanings but only one is to be found in the dataset. Therefore all corresponding rows are being removed
# Out:
#        id        mwe literal_meaning               _1    _2    _3  0/1  \
# 4473  265  leap year       jump year  bissextile year  None  None    0
# 4474  265  leap year       jump year  bissextile year  None  None    0
# 4475  265  leap year       jump year  bissextile year  None  None    0
# 4476  265  leap year       jump year  bissextile year  None  None    0
# 4477  265  leap year       jump year  bissextile year  None  None    0
# 4478  265  leap year       jump year  bissextile year  None  None    0
# 4479  265  leap year       jump year  bissextile year  None  None    0
# 4480  265  leap year       jump year  bissextile year  None  None    0
# 4481  265  leap year       jump year  bissextile year  None  None    0
# 4482  265  leap year       jump year  bissextile year  None  None    0
# 4483  265  leap year       jump year  bissextile year  None  None    0
# 4484  265  leap year       jump year  bissextile year  None  None    0
# 4485  265  leap year       jump year  bissextile year  None  None    0
# 4486  265  leap year       jump year  bissextile year  None  None    0
# 4487  265  leap year       jump year  bissextile year  None  None    0
# 4488  265  leap year       jump year  bissextile year  None  None    0
#
#          fine_grained                                              prior  \
# 4473  bissextile year  According to history.com, the leap day was ori...
# 4474  bissextile year  Prior to this, most of the Roman world and Eur...
# 4475  bissextile year  It just means that a day is added to the month...
# 4476  bissextile year  In February and March last year, 593 speeding ...
# 4477  bissextile year  Apparently women were also expected to have to...
# 4478  bissextile year  But what about metaphorical leaping, as in tak...
# 4479  bissextile year  No town of its size in New York state has a la...
# 4480  bissextile year  To me, having to wait that long for presents f...
# 4481  bissextile year                  It is the Silas Marner of months.
# 4482  bissextile year  Over the last several decades, the precision o...
# 4483  bissextile year  The bachelors who figure they will be safe dur...
# 4484  bissextile year  While gaining an extra day this year seems lit...
# 4485  bissextile year  In his younger days friends teased him a bit a...
# 4486  bissextile year  Having a baby on a leap day is pretty rare, so...
# 4487  bissextile year  In China, for example, the leap year has an ex...
# 4488  bissextile year  As we'll be seeing in the next article, leap y...
#
#                                                sentence  \
# 4473  Caesar then created the leap year calendar to ...
# 4474  In order to try and link the calendar up to th...
# 4475  Precisely, it takes 365 days, 5 hours, 48 minu...
# 4476  The error was a result of the issuing computer...
# 4477  Another theory involves Queen Margaret of Scot...
# 4478  Our presidential candidates take advantage of ...
# 4479  In leap year they hold the balance of power an...
# 4480  Later, I came to know that they did celebrate ...
# 4481  February is 28 Sunday afternoons in Philadelph...
# 4482  Leap seconds have been added in the past to ke...
# 4483  The marriage license records show that El Paso...
# 4484  The year 2000 is divisible by 4, which would q...
# 4485  Baumann said a woman who works at the U.S. For...
# 4486  Considering how special it is for a baby to be...
# 4487  Likewise, the Ethiopian calendar consists of 1...
# 4488  In fact, you might be surprised just how much ...
#
#                                                   after
# 4473  Feb. 29 happens every four years, because the ...
# 4474  The problem was that since the actual solar ye...
# 4475  Now another thing that comes to mind is the re...
# 4476  The fault occurred over 14 days from February ...
# 4477  This one is rather questionable however as Que...
# 4478  The years give them an extra day to campaign a...
# 4479  The Sidney girls can do it, and if they let le...
# 4480  Did you know that an old Irish tradition allow...
# 4481  And 29 Mondays further animated by calls from ...
# 4482  Interestingly, since scientists began measurin...
# 4483  Twelve years ago, the marriage license clerks,...
# 4484  However, it is divisible by 400, which, once a...
# 4485  Others outside the basin include actor Dennis ...
# 4486  Their energy is creative, receptive, and often...
# 4487  Hebrew and Buddhist ancient calendars also fol...
# 4488  Rob Gravelle resides in Ottawa, Canada, and is...

# %%
# Drop MWEs that don't have both a compositional and a non-compositional meaning
data_df, dropped_rows = drop_rows_with_single_meaning(data_df)
print(f"Number of rows dropped: {len(dropped_rows)}")

data_df.head(10)
# Out:
# Number of rows dropped: 3200
#     id         mwe literal_meaning                _1    _2    _3  0/1  \
# 58  38  sacred cow      divine cow  above criticism   None  None    1
# 61  38  sacred cow      divine cow  above criticism   None  None    0
# 62  38  sacred cow      divine cow  above criticism   None  None    0
# 63  38  sacred cow      divine cow  above criticism   None  None    0
# 64  38  sacred cow      divine cow  above criticism   None  None    0
# 65  38  sacred cow      divine cow  above criticism   None  None    0
# 66  38  sacred cow      divine cow  above criticism   None  None    0
# 67  38  sacred cow      divine cow  above criticism   None  None    0
# 68  38  sacred cow      divine cow  above criticism   None  None    0
# 69  38  sacred cow      divine cow  above criticism   None  None    0
#
#         fine_grained                                              prior  \
# 58        divine cow     Like beef, pork is also forbidden in Hinduism.
# 61  above criticism   Besides, the Rights group said the Minister of...
# 62  above criticism   But in the Macquarie judgment, Judge Sandy Str...
# 63  above criticism   The Commissioner of Police, CP Abutu Yaro, who...
# 64  above criticism   The committee shall come up with findings and ...
# 65  above criticism   The House has now resumed discussion on a moti...
# 66  above criticism   We will deal with perpetrators with the force ...
# 67  above criticism   The end was that nobody should be denied healt...
# 68  above criticism   Although, the motion against NAB was talked ou...
# 69  above criticism   The expectations of winning I don’t think have...
#
#                                              sentence  \
# 58  However, unlike the sacred cow, the pig repres...
# 61  The Rights group said the ministry has continu...
# 62  Barwick says historically there has been littl...
# 63  The state police boss also directed the full e...
# 64  There is no sacred cow under the law of probit...
# 65  Taking floor of the House, Senator Mohsin Aziz...
# 66  Going further with seriousness, Ajimobi went o...
# 67  By making a sacred cow of the latter we have b...
# 68  No one is sacred cow, no one is above accounta...
# 69  I do think there is this undercurrent of 'They...
#
#                                                 after
# 58  This is considered to be particularly impure a...
# 61  HURIWA recalled that the Federal Government on...
# 62  The Fair Work Act is clear that employers cann...
# 63  No stone would be left unturned because we are...
# 64  For a deterrent in future, the Chairman shall ...
# 65  He said he presented himself before National A...
# 66  Anyone who is implicated in the endemic and se...
# 67  An anonymous nurse working in intensive care s...
# 68  It’s true that when NAB summoned me I was in R...
# 69                It’s kind of become an entitlement.

# %%
data_df['prior_tokens'] = data_df['prior'].apply(lambda x: [token.text for token in nlp(x)])
data_df['sentence_tokens'] = data_df['sentence'].apply(lambda x: [token.text for token in nlp(x)])
data_df['after_tokens'] = data_df['after'].apply(lambda x: [token.text for token in nlp(x)])

# %%
data_df['tokenized_mwe'] = data_df['mwe'].apply(tokenizer.tokenize)
# data_df.insert(data_df.columns.get_loc('mwe') + 1, 'tokenized_mwe', data_df['tokenized_mwe'])
print(len(data_df))
data_df.head()
# Out:
# 668
#     id         mwe literal_meaning                _1    _2    _3  0/1  \
# 58  38  sacred cow      divine cow  above criticism   None  None    1
# 61  38  sacred cow      divine cow  above criticism   None  None    0
# 62  38  sacred cow      divine cow  above criticism   None  None    0
# 63  38  sacred cow      divine cow  above criticism   None  None    0
# 64  38  sacred cow      divine cow  above criticism   None  None    0
#
#         fine_grained                                              prior  \
# 58        divine cow     Like beef, pork is also forbidden in Hinduism.
# 61  above criticism   Besides, the Rights group said the Minister of...
# 62  above criticism   But in the Macquarie judgment, Judge Sandy Str...
# 63  above criticism   The Commissioner of Police, CP Abutu Yaro, who...
# 64  above criticism   The committee shall come up with findings and ...
#
#                                              sentence  \
# 58  However, unlike the sacred cow, the pig repres...
# 61  The Rights group said the ministry has continu...
# 62  Barwick says historically there has been littl...
# 63  The state police boss also directed the full e...
# 64  There is no sacred cow under the law of probit...
#
#                                                 after  \
# 58  This is considered to be particularly impure a...
# 61  HURIWA recalled that the Federal Government on...
# 62  The Fair Work Act is clear that employers cann...
# 63  No stone would be left unturned because we are...
# 64  For a deterrent in future, the Chairman shall ...
#
#                                          prior_tokens  \
# 58  [Like, beef, ,, pork, is, also, forbidden, in,...
# 61  [Besides, ,, the, Rights, group, said, the, Mi...
# 62  [But, in, the, Macquarie, judgment, ,, Judge, ...
# 63  [The, Commissioner, of, Police, ,, CP, Abutu, ...
# 64  [The, committee, shall, come, up, with, findin...
#
#                                       sentence_tokens  \
# 58  [However, ,, unlike, the, sacred, cow, ,, the,...
# 61  [The, Rights, group, said, the, ministry, has,...
# 62  [Barwick, says, historically, there, has, been...
# 63  [The, state, police, boss, also, directed, the...
# 64  [There, is, no, sacred, cow, under, the, law, ...
#
#                                          after_tokens  tokenized_mwe
# 58  [This, is, considered, to, be, particularly, i...  [sacred, cow]
# 61  [HURIWA, recalled, that, the, Federal, Governm...  [sacred, cow]
# 62  [The, Fair, Work, Act, is, clear, that, employ...  [sacred, cow]
# 63  [No, stone, would, be, left, unturned, because...  [sacred, cow]
# 64  [For, a, deterrent, in, future, ,, the, Chairm...  [sacred, cow]

# %%
dropped_rows = data_df[~data_df.apply(lambda row: all(token in row['sentence_tokens'] for token in row['tokenized_mwe']), axis=1)]
print(f"There are {len(dropped_rows)} dropped lemmatization-related issues.")
for index, row in dropped_rows.iterrows():
    print(f"Index: {index} - MWE : {row['tokenized_mwe']}")
    print("Sentence Tokens:", row['sentence_tokens'])

data_df = data_df[data_df.apply(lambda row: all(token in row['sentence_tokens'] for token in row['tokenized_mwe']), axis=1)]
# Out:
# There are 36 dropped lemmatization-related issues.
# Index: 178 - MWE : ['silver', 'lining']
# Sentence Tokens: ['Probably', 'because', 'there', 'have', 'been', 'so', 'many', 'bad', 'things', 'happening', 'from', 'which', 'silver', 'linings', 'can', 'emerge', '.']
# Index: 182 - MWE : ['silver', 'lining']
# Sentence Tokens: ['So', ',', 'there', 'are', 'silver', 'linings', 'to', 'Covid-19', 'after', 'all', '!']
# Index: 188 - MWE : ['silver', 'lining']
# Sentence Tokens: ['It', "'s", 'why', 'Stager', 'never', 'takes', 'these', 'silver', 'linings', 'for', 'granted', ',', 'knowing', 'the', 'hardship', 'and', 'sacrifice', 'that', 'made', 'them', 'shine', '.']
# Index: 312 - MWE : ['top', 'dog']
# Sentence Tokens: ['My', 'stepdad', 'tried', 'hard', 'to', 'prove', 'me', 'wrong', ',', 'telling', 'me', 'about', 'how', 'they', "'re", '"', 'the', 'top', 'dogs', '"', 'and', 'they', "'re", 'in', 'India', ',', 'China', ',', 'etc', '.']
# Index: 533 - MWE : ['public', 'service']
# Sentence Tokens: ['Public', 'service', 'is', 'the', 'backbone', 'of', 'local', 'and', 'state', 'government', '.']
# Index: 937 - MWE : ['bad', 'hat']
# Sentence Tokens: ['Almost', 'immediately', ',', 'Madeline', 'does', 'not', 'trust', 'the', 'boy', '(', 'known', 'as', 'Pepito', ')', ',', 'judging', 'him', 'to', 'be', 'a', '"', 'Bad', 'Hat', '"', 'as', 'he', 'wears', 'a', 'very', 'remarkable', 'black', 'hat', 'and', 'makes', 'mocking', 'faces', 'at', 'the', 'school', 'through', 'the', 'window', '.']
# Index: 938 - MWE : ['bad', 'hat']
# Sentence Tokens: ['Lead', 'singer', 'Alexander', 'was', 'at', 'times', 'was', 'labeled', 'as', 'a', '“', 'Bad', 'Hat', '”', 'by', 'her', 'parents', 'whenever', 'she', 'acted', 'up', '.']
# Index: 1192 - MWE : ['sacred', 'cow']
# Sentence Tokens: ['Above', 'all', ',', 'sacred', 'cows', 'are', 'not', 'essential', 'to', 'the', 'fundamentals', 'of', 'Christianity', ',', 'but', 'people', 'treat', 'them', 'as', 'if', 'they', 'are', '.']
# Index: 1580 - MWE : ['ground', 'floor']
# Sentence Tokens: ['We', 'respectfully', 'have', 'maximized', 'our', 'transparency', 'on', 'the', 'Upper', 'Floor', 'and', 'Ground', 'Floor', '.']
# Index: 1697 - MWE : ['hard', 'shoulder']
# Sentence Tokens: ['Ever', 'since', 'Jason', 'died', ',', 'I', 'have', 'been', 'determined', 'to', 'bring', 'about', 'change', 'to', 'ensure', 'more', 'families', 'do', "n't", 'go', 'through', 'the', 'heartbreak', 'of', 'losing', 'a', 'loved', 'one', 'by', 'the', 'completely', 'nonsensical', 'removal', 'of', 'hard', 'shoulders', 'on', 'busy', 'motorways', ',', 'without', 'adequate', 'safeguards', 'being', 'in', 'place', '.', '”']
# Index: 1746 - MWE : ['grass', 'root']
# Sentence Tokens: ['Sometimes', ',', 'however', ',', 'grass', 'roots', 'rot', 'due', 'to', 'too', 'much', 'water', 'and', 'the', 'presence', 'of', 'a', 'fungal', 'disease', '.']
# Index: 1747 - MWE : ['grass', 'root']
# Sentence Tokens: ['The', 'rotting', 'grass', 'roots', 'look', 'dark', 'brown', 'or', 'black', '.']
# Index: 1748 - MWE : ['grass', 'root']
# Sentence Tokens: ['Overly', 'wet', 'conditions', 'coupled', 'with', 'poor', 'drainage', 'create', 'the', 'perfect', 'environment', 'for', 'fungi', 'to', 'rot', 'grass', 'roots', '.']
# Index: 2035 - MWE : ['baby', 'blues']
# Sentence Tokens: ['Baby', 'blues', 'usually', 'ebbs', 'within', 'a', 'couple', 'of', 'weeks', '.']
# Index: 2037 - MWE : ['baby', 'blues']
# Sentence Tokens: ['Symptoms', 'of', 'the', 'Baby', 'Blues', 'usually', 'appear', 'within', 'the', 'first', 'week', 'or', 'two', 'following', 'delivery', ',', 'and', 'may', 'last', 'for', 'several', 'weeks', 'following', '.']
# Index: 2041 - MWE : ['baby', 'blues']
# Sentence Tokens: ['Some', 'symptoms', 'of', 'PPD', 'are', 'similar', 'to', 'the', 'Baby', 'Blues', ',', 'but', 'become', 'more', 'intense', '.']
# Index: 2178 - MWE : ['nest', 'egg']
# Sentence Tokens: ['It', 'shows', 'geographic', 'regions', 'where', 'people', 'are', 'succeeding', 'and', 'where', 'they', 'face', 'the', 'greatest', 'difficulty', 'in', 'building', 'and', 'nurturing', 'their', 'nest', 'eggs', '.']
# Index: 2180 - MWE : ['nest', 'egg']
# Sentence Tokens: ['He', 'encourages', 'readers', 'to', 'take', 'steps', 'to', 'prevent', 'future', 'crises', 'and', 'protect', 'their', 'own', 'nest', 'eggs', ':']
# Index: 2234 - MWE : ['glass', 'ceiling']
# Sentence Tokens: ['Today', "'s", 'progress', 'is', 'built', 'on', 'the', 'legacy', 'of', 'the', 'women', 'who', 'came', 'before', '–', 'the', 'trailblazers', ',', 'like', 'Kamala', ',', 'who', 'raised', 'their', 'voices', ',', 'marched', 'for', 'their', 'rights', ',', 'and', 'ran', 'for', 'elected', 'office', ';', 'the', 'women', 'who', 'cracked', 'glass', 'ceilings', 'so', 'that', 'other', 'women', 'could', 'shatter', 'them', ',', '"', 'Hotchner', 'said', '.']
# Index: 2245 - MWE : ['glass', 'ceiling']
# Sentence Tokens: ['Chief', "'s", 'mission', 'is', 'to', 'drive', 'women', 'into', 'positions', 'of', 'power', 'and', 'keep', 'them', 'there', '–', 'we', 'exist', 'to', 'support', 'ascendant', 'women', 'to', 'break', 'glass', 'ceilings', ',', 'retain', 'their', 'seats', 'at', 'the', 'table', ',', 'and', 'create', 'lines', 'of', 'succession', 'for', 'future', 'women', 'leaders', ',', '"', 'said', 'Lindsay', 'Kaplan', ',', 'who', 'co', '-', 'founded', 'Chief', 'in', '2019', 'with', 'Carolyn', 'Childers', '.']
# Index: 2498 - MWE : ['blue', 'blood']
# Sentence Tokens: ['In', 'the', 'grand', 'scheme', 'of', 'things', ',', 'it', 'wo', "n't", 'be', 'long', 'before', 'college', 'basketball', "'s", 'blue', 'bloods', 'are', 'back', 'to', 'dominating', 'the', 'sport', '.']
# Index: 2500 - MWE : ['blue', 'blood']
# Sentence Tokens: ['But', 'more', 'shockingly', ',', 'the', 'pandemic', 'has', 'seemingly', 'toppled', 'the', 'blue', 'bloods', 'of', 'the', 'sport', ',', 'at', 'least', 'for', 'this', 'season', '.']
# Index: 2503 - MWE : ['blue', 'blood']
# Sentence Tokens: ['But', 'traditional', 'blue', 'bloods', 'in', 'the', 'Big', 'Ten', ',', 'Michigan', 'State', 'and', 'Indiana', ',', 'are', "n't", 'doing', 'so', 'hot', ',', 'either', '.']
# Index: 2616 - MWE : ['gold', 'mine']
# Sentence Tokens: ['Shandong', 'Wucailong', 'Investment', 'is', 'a', 'subsidiary', 'of', 'Zhaojin', 'Mining', ',', 'China', '’s', 'fourth', 'largest', 'gold', 'miner', ',', 'which', 'was', 'listed', 'on', 'the', 'Hong', 'Kong', 'stock', 'exchange', 'in', 'December', '2006', '.']
# Index: 2691 - MWE : ['brass', 'ring']
# Sentence Tokens: ['The', 'outer', 'brass', 'rings', 'can', 'be', 'used', 'for', 'telling', 'the', 'time', 'in', 'both', 'Western', 'and', 'Chinese', 'cultures', '.']
# Index: 2735 - MWE : ['acid', 'test']
# Sentence Tokens: ['The', 'reduction', 'in', 'prices', 'of', 'nucleic', 'acid', 'testing', 'will', 'help', 'further', 'ease', 'the', 'public', 'pressure', 'on', 'testing', ',', 'Zeng', 'Yixin', ',', 'deputy', 'a', 'director', 'of', 'the', 'NHC', ',', 'told', 'a', 'press', 'conference', 'of', 'the', 'State', 'Council', 'on', 'Wednesday', '.']
# Index: 2736 - MWE : ['acid', 'test']
# Sentence Tokens: ['By', 'the', 'end', 'of', '2020', ',', 'more', 'than', 'half', 'of', 'China', "'s", 'provinces', 'had', 'lowered', 'the', 'prices', 'of', 'novel', 'coronavirus', 'nucleic', 'acid', 'testing', 'in', 'public', 'hospitals', '.']
# Index: 2738 - MWE : ['acid', 'test']
# Sentence Tokens: ['China', "'s", 'daily', 'nucleic', 'acid', 'testing', 'capacity', 'surpasses', '15', 'million']
# Index: 2963 - MWE : ['big', 'cheese']
# Sentence Tokens: ['Back', 'when', 'I', 'was', 'a', 'rookie', 'reporter', 'in', 'Galveston', ',', 'Texas', ',', 'and', 'I', 'was', 'writing', 'a', 'story', 'about', 'corporal', 'punishment', '(', 'spanking', ')', 'in', 'schools', ',', 'the', 'school', 'superintendent', '(', 'Big', 'Cheese', ')', 'said', 'the', 'word', '“', 'paddle', '”', 'was', 'too', 'harsh', 'a', 'word', 'for', 'the', 'device', 'used', 'to', 'whack', 'kids', '’', 'backsides', '.']
# Index: 2976 - MWE : ['big', 'cheese']
# Sentence Tokens: ['The', 'Big', 'Cheese', ',', 'the', 'figure', 'high', 'ranking', 'in', 'the', 'organization', 'who', 'selfishly', 'and', 'strategically', 'would', 'n’t', ',', 'and', 'did', 'n’t', ',', 'get', 'his', 'fingers', 'dirty', ',', 'defends', 'himself', 'saying', 'that', 'his', 'underlings', 'were', 'acting', 'on', 'their', 'own', ':', '“', 'I', 'had', 'nothing', 'to', 'do', 'with', 'it', '.', '”']
# Index: 4269 - MWE : ['rat', 'run']
# Sentence Tokens: ['It', 'is', 'very', 'disappointing', 'that', 'there', 'are', 'a', 'number', 'of', 'drivers', 'locally', 'not', 'using', 'the', 'official', 'diversions', 'and', 'as', 'such', 'are', 'using', 'local', 'villages', 'like', 'Great', 'Broughton', 'as', 'rat', 'runs', '.']
# Index: 4272 - MWE : ['rat', 'run']
# Sentence Tokens: ['A', 'council', 'spokesman', 'said', ':', '"', 'The', 'issue', 'of', 'rat', 'running', 'was', 'considered', 'in', 'some', 'detail', 'at', 'the', 'time', 'of', 'the', 'planning', 'application', 'back', 'in', '2011', ',', 'by', 'the', 'council', 'and', 'Transport', 'for', 'Greater', 'Manchester', '.']
# Index: 4276 - MWE : ['rat', 'run']
# Sentence Tokens: ['He', 'said', 'it', 'was', 'clear', 'there', 'was', 'a', 'problem', 'with', 'rat', 'running', 'through', 'the', 'estate', 'and', 'something', 'had', 'to', 'be', 'done', '“', 'to', 'manage', 'the', 'through', 'traffic', '”', '.']
# Index: 4277 - MWE : ['rat', 'run']
# Sentence Tokens: ['This', 'is', 'likely', 'due', 'to', 'cars', 'choosing', 'to', 'still', 'avoid', 'the', 'main', 'road', 'into', 'Tolworth', 'and', 'using', 'the', 'smaller', 'residential', 'roads', 'as', "'", 'rat', 'runs', "'", '.']
# Index: 4278 - MWE : ['rat', 'run']
# Sentence Tokens: ['Bolton', 'Council', 'says', 'it', 'consulted', 'with', 'Transport', 'for', 'Greater', 'Manchester', 'over', 'the', 'potential', 'issue', 'of', '"', 'rat', 'running', '"', 'and', 'that', ',', 'if', 'vehicles', 'were', 'to', 'bypass', 'the', 'development', 'site', ',', 'this', 'would', 'be', 'done', 'over', 'a', '"', 'wide', 'network', '"', '.']
# Index: 4587 - MWE : ['best', 'man']
# Sentence Tokens: ['Gary', 'Neville', 'identifies', '"', 'permanent', 'change', '"', 'to', 'Ole', 'Gunnar', 'Solskjaer', "'s", 'best', 'Man', 'Utd', 'XI']

# %%
sentences = 0
for col in ['prior', 'sentence', 'after']:
        sentences += len([sentence for sentence in data_df[col]])

print(f"There are {sentences:,} sentences in the dataset")
# Out:
# There are 1,896 sentences in the dataset

# %%
# Function to preprocess the data for other files
data_df = retrieve_preprocessed_df(print_ignored=True)
data_df.head()
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# We drop 777 ProperNoun and MetaUsage rows out of 4645.
# Number of dropped single-meaning-mwe rows: 3200
# There are 36 dropped lemmatization-related issues. For more detail uncomment what comes next in the function.
# There are 1,896 remaining sentences in the dataset.
#     id         mwe literal_meaning                _1    _2    _3  0/1  \
# 58  38  sacred cow      divine cow  above criticism   None  None    1
# 61  38  sacred cow      divine cow  above criticism   None  None    0
# 62  38  sacred cow      divine cow  above criticism   None  None    0
# 63  38  sacred cow      divine cow  above criticism   None  None    0
# 64  38  sacred cow      divine cow  above criticism   None  None    0
#
#         fine_grained                                              prior  \
# 58        divine cow     Like beef, pork is also forbidden in Hinduism.
# 61  above criticism   Besides, the Rights group said the Minister of...
# 62  above criticism   But in the Macquarie judgment, Judge Sandy Str...
# 63  above criticism   The Commissioner of Police, CP Abutu Yaro, who...
# 64  above criticism   The committee shall come up with findings and ...
#
#                                              sentence  \
# 58  However, unlike the sacred cow, the pig repres...
# 61  The Rights group said the ministry has continu...
# 62  Barwick says historically there has been littl...
# 63  The state police boss also directed the full e...
# 64  There is no sacred cow under the law of probit...
#
#                                                 after  \
# 58  This is considered to be particularly impure a...
# 61  HURIWA recalled that the Federal Government on...
# 62  The Fair Work Act is clear that employers cann...
# 63  No stone would be left unturned because we are...
# 64  For a deterrent in future, the Chairman shall ...
#
#                                          prior_tokens  \
# 58  [Like, beef, ,, pork, is, also, forbidden, in,...
# 61  [Besides, ,, the, Rights, group, said, the, Mi...
# 62  [But, in, the, Macquarie, judgment, ,, Judge, ...
# 63  [The, Commissioner, of, Police, ,, CP, Abutu, ...
# 64  [The, committee, shall, come, up, with, findin...
#
#                                       sentence_tokens  \
# 58  [However, ,, unlike, the, sacred, cow, ,, the,...
# 61  [The, Rights, group, said, the, ministry, has,...
# 62  [Barwick, says, historically, there, has, been...
# 63  [The, state, police, boss, also, directed, the...
# 64  [There, is, no, sacred, cow, under, the, law, ...
#
#                                          after_tokens  tokenized_mwe
# 58  [This, is, considered, to, be, particularly, i...  [sacred, cow]
# 61  [HURIWA, recalled, that, the, Federal, Governm...  [sacred, cow]
# 62  [The, Fair, Work, Act, is, clear, that, employ...  [sacred, cow]
# 63  [No, stone, would, be, left, unturned, because...  [sacred, cow]
# 64  [For, a, deterrent, in, future, ,, the, Chairm...  [sacred, cow]
